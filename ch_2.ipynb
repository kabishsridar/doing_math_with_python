# %% [markdown]
# ## from pylab import plot, show

# %%
x_numbers = [1, 2, 3]
y_numbers = [2, 4, 6]

# %%
plot(x_numbers, y_numbers)
show()

# %%
x = [1,2,3]
y = [2,5,6]
plot(x,y)
show()

# %%
x = [1,2,3]
y = [2,5,6]
plot(x,y, marker='o')
show()

# %%
x = [1,2,3]
y = [2,5,6]
plot(x,y, marker = '>') # marker can be x, +, *, o, >, <, ^
show()

# %%
nyc_temp = [53.9, 56.3, 56.4, 53.4, 54.5, 55.8, 56.8, 55.0, 55.3, 54.0, 56.7, 56.4, 57.3]
plot(nyc_temp, marker='o')
show()

# %%
months = range(1, 13)
nyc_temp_2000 = [31.3, 37.3, 47.2, 51.0, 63.5, 71.3, 72.3, 72.7, 66.0, 57.0, 45.3, 31.1]
nyc_temp_2006 = [40.9, 35.7, 43.1, 55.7, 63.1, 71.0, 77.9, 75.8, 66.6, 56.2, 51.9, 43.6]
nyc_temp_2012 = [37.3, 40.9, 50.9, 54.8, 65.1, 71.0, 78.8, 76.7, 68.8, 58.0, 43.9, 41.5]
months = range(1, 13)
plot(months, nyc_temp_2000, months, nyc_temp_2006, months, nyc_temp_2012)
show()

# %%
plot(months, nyc_temp_2000)
show()

# %%
from pylab import legend, title, xlabel, ylabel

# %%
plot(months, nyc_temp_2000, months, nyc_temp_2006, months, nyc_temp_2012)
title('Average monthly temperature in NYC')
xlabel('Month')
ylabel('Temperature')
legend([2000, 2006, 2012]) # the side box is through legend method
show()

# %%
import matplotlib.pyplot as plt

# %%
def create_graph():
    x = [1,2,3]
    y = [2,4,6]
    plt.plot(x, y)
    plt.show()
if __name__ == "__main__":
    create_graph()

# %%
from pylab import plot, savefig

# %%
plot(x, y)
savefig('C:\\doing_math_with_python\\mygraph.png')

# %%
import matplotlib.pyplot as plt

# %%
def draw_graph(x, y):
    plt.plot(x, y, marker='o')
    plt.xlabel('Distance in meters')
    plt.ylabel('Gravitational force in newtons')
    plt.title('Gravitational force and distance')
    plt.show()
def generate_F_r():
    r = range(100, 1001, 50)
    F = []
    G = 6.674*(10**-11)
    m1 = 0.5
    m2 = 1.5
    for dist in r:
        force = G*(m1*m2)/(dist**2)
        F.append(force)
    draw_graph(r, F)
if __name__ == "__main__":
    generate_F_r()

# %%
from matplotlib import pyplot as plt
import math

def draw_graph(x, y):
    plt.plot(x, y)
    plt.xlabel('x-coordinate')
    plt.ylabel('y-coordinate')
    plt.title('Projection motion of a ball')

def frange(start, final, interval):
    numbers = []
    while start < final:
        numbers.append(start)
        start = start + interval
    return numbers
def draw_trajectory(u, theta):
    theta = math.radians(theta)
    g = 9.8
    t_flight = 2*u*math.sin(theta)/g
    intervals = frange(0, t_flight, 0.001)
    x = []
    y = []
    for t in intervals:
        x.append(u*math.cos(theta) * t)
        y.append(u*math.sin(theta) * t - 0.5*g*t*t)
    draw_graph(x, y)
if __name__ == '__main__':
    try:
        u = float(input('Enter the initial velocity (m/s): '))
        theta = float(input('Enter the angle of projection (degrees): '))
    except ValueError:
        print('You entered an invalid input')
    else:
        draw_trajectory(u, theta)
        plt.show()
# Out:
# Enter the initial velocity (m/s):  25
# Enter the angle of projection (degrees):  60

# %%
from matplotlib import pyplot as plt
import math

def draw_graph(x, y):
    plt.plot(x, y)
    plt.xlabel('x-coordinate')
    plt.ylabel('y-coordinate')
    plt.title('Projection motion of a ball')

def frange(start, final, interval):
    numbers = []
    while start < final:
        numbers.append(start)
        start = start + interval
    return numbers
def draw_trajectory(u, theta):
    theta = math.radians(theta)
    g = 9.8
    t_flight = 2*u*math.sin(theta)/g
    intervals = frange(0, t_flight, 0.001)
    x = []
    y = []
    for t in intervals:
        x.append(u*math.cos(theta) * t)
        y.append(u*math.sin(theta) * t - 0.5*g*t*t)
    draw_graph(x, y)
if __name__ == '__main__':
    # List of three different initial velocities
    u_list = [20, 40, 60] 
    theta = 45
    for u in u_list:
        draw_trajectory(u, theta)
    # Add a legend and show the graph
    plt.legend(['20', '40', '60']) 
    plt.show()

# %%
import matplotlib.pyplot as plt

# %%
weather = [30,29,26, 25,24, 23, 24, 22]
time = ['12pm','3pm','6pm','9pm','12am','3am', '6am','9am']

# %%
plt.plot(time, weather, label='New York', marker='o')
plt.legend()
plt.show()

# %%
x_lst = [-3,-2,-1, 1, 2, 3, 4, 5, 6, 7]
x_cord = []
y_cord = []
for x in x_lst:
    y = (x **2) + (2*x) + 1
    x_cord.append(x)
    y_cord.append(y)
plt.plot(x_cord, y_cord, marker='o')
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
#3rd will be done late

# %%
num_categories = int(input("Enter number of categories: "))
categories_lst = []
expenditures_lst = []
for category in range(num_categories):
    category = input("Enter category: ")
    categories_lst.append(category)
    expenditure = float(input("Expenditure: "))
    expenditures_lst.append(expenditure)
print(categories_lst)
print(expenditures_lst)
plt.barh(categories_lst, expenditures_lst)
plt.show()
# Out:
# Enter number of categories:  4
# Enter category:  Food
# Expenditure:  70
# Enter category:  Transportation
# Expenditure:  35
# Enter category:  Entertainment
# Expenditure:  30
# Enter category:  Phone
# Expenditure:  30
# ['Food', 'Transportation', 'Entertainment', 'Phone']
# [70.0, 35.0, 30.0, 30.0]

# %%
def fibo(n): 
    if n == 1: 
        return [1]
    if n == 2:
        return [1, 1]
    # n > 2
    a = 1
    b = 1
    # First two members of the series
    series = [a, b]
    for i in range(n):
        c = a + b
        series.append(c) 
        a = b
        b = c
    return series 
fib_series = fibo(100)
ratios = [fib_series[i+1] / fib_series[i] for i in range(1, len(fib_series)-1)]
golden_ratio = 1.61803398875

plt.plot(ratios, label='Ratios')
plt.title('Ratio Between Consecutive Fibonacci Numbers')
plt.grid(True)
plt.xlabel('NO.')
plt.ylabel('Ratio')
plt.show()

# %%
trajectories_num = int(input("How many trajectories? "))
u = []
theta = []
for i in range(trajectories_num):
    initial_velocity = int(input(f"Enter the initial velocity for trajectory {i+1} (m/s): "))
    u.append(initial_velocity)
    angle = int(input(f"Enter the angle of projection for trajectory {i+1} (degrees): "))
    theta.append(angle)
print(u)
print(theta)
plt.plot(u, theta)
# Out:
# How many trajectories?  3
# Enter the initial velocity for trajectory 1 (m/s):  45
# Enter the angle of projection for trajectory 1 (degrees):  45
# Enter the initial velocity for trajectory 2 (m/s):  60
# Enter the angle of projection for trajectory 2 (degrees):  45
# Enter the initial velocity for trajectory 3 (m/s):  45
# Enter the angle of projection for trajectory 3 (degrees):  90
# [45, 60, 45]
# [45, 45, 90]
